# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (23.0.1)
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (3.7)
# Collecting wordcloud==1.9.3
#   Downloading wordcloud-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (513 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.6/513.6 kB 8.8 MB/s eta 0:00:00
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 46.3 MB/s eta 0:00:00
# Collecting unidecode==1.3.8
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 44.3 MB/s eta 0:00:00
# Collecting emoji
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 60.0 MB/s eta 0:00:00
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 5.9 MB/s eta 0:00:00
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 11.3 MB/s eta 0:00:00
# Collecting kbbi
#   Downloading kbbi-0.4.3-py3-none-any.whl (12 kB)
# Collecting flair
#   Downloading flair-0.13.1-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 55.0 MB/s eta 0:00:00
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting nlp_id==0.1.15.0
#   Downloading nlp_id-0.1.15.0.tar.gz (54.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 39.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud==1.9.3->-r ./requirements.txt (line 3)) (1.23.4)
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud==1.9.3->-r ./requirements.txt (line 3)) (9.2.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud==1.9.3->-r ./requirements.txt (line 3)) (3.6.0)
# Collecting scikit-learn==1.2.2
#   Downloading scikit_learn-1.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 121.0 MB/s eta 0:00:00
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.7 MB/s eta 0:00:00
# Collecting pytest==7.3.1
#   Downloading pytest-7.3.1-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.5/320.5 kB 47.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->-r ./requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->-r ./requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->-r ./requirements.txt (line 2)) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->-r ./requirements.txt (line 2)) (2022.9.13)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pytest==7.3.1->nlp_id==0.1.15.0->-r ./requirements.txt (line 17)) (1.0.0)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pytest==7.3.1->nlp_id==0.1.15.0->-r ./requirements.txt (line 17)) (21.3)
# Requirement already satisfied: scipy>=1.3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn==1.2.2->nlp_id==0.1.15.0->-r ./requirements.txt (line 17)) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn==1.2.2->nlp_id==0.1.15.0->-r ./requirements.txt (line 17)) (3.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from deep-translator->-r ./requirements.txt (line 9)) (2.28.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from deep-translator->-r ./requirements.txt (line 9)) (4.11.1)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting pptree>=3.1
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch!=1.8,>=1.5.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->-r ./requirements.txt (line 15)) (1.12.1)
# Requirement already satisfied: boto3>=1.20.27 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->-r ./requirements.txt (line 15)) (1.24.95)
# Collecting segtok>=1.5.11
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting more-itertools>=8.13.0
#   Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 11.4 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.4/346.4 kB 53.4 MB/s eta 0:00:00
# Collecting janome>=0.4.2
#   Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 84.0 MB/s eta 0:00:00
# Collecting gdown>=4.4.0
#   Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Collecting transformer-smaller-training-vocab>=0.2.3
#   Downloading transformer_smaller_training_vocab-0.3.3-py3-none-any.whl (14 kB)
# Collecting wikipedia-api>=0.5.7
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Collecting gensim>=4.2.0
#   Downloading gensim-4.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 72.3 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.8.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->-r ./requirements.txt (line 15)) (4.9.1)
# Collecting bpemb>=0.3.2
#   Downloading bpemb-0.3.5-py3-none-any.whl (19 kB)
# Collecting sqlitedict>=2.0.0
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: urllib3<2.0.0,>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->-r ./requirements.txt (line 15)) (1.26.12)
# Collecting langdetect>=1.0.9
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 92.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from flair->-r ./requirements.txt (line 15)) (2.8.2)
# Collecting mpld3>=0.3
#   Downloading mpld3-0.5.10-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 41.0 MB/s eta 0:00:00
# Collecting semver<4.0.0,>=3.0.0
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Collecting transformers[sentencepiece]<5.0.0,>=4.18.0
#   Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 122.0 MB/s eta 0:00:00
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ftfy>=6.1.0
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 14.4 MB/s eta 0:00:00
# Collecting pytorch-revgrad>=0.2.0
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting conllu>=4.0
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->-r ./requirements.txt (line 15)) (0.9.0)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r ./requirements.txt (line 9)) (2.3.2.post1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from boto3>=1.20.27->flair->-r ./requirements.txt (line 15)) (1.0.1)
# Requirement already satisfied: botocore<1.28.0,>=1.27.95 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from boto3>=1.20.27->flair->-r ./requirements.txt (line 15)) (1.27.95)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from boto3>=1.20.27->flair->-r ./requirements.txt (line 15)) (0.6.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 96.7 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from deprecated>=1.2.13->flair->-r ./requirements.txt (line 15)) (1.14.1)
# Collecting wcwidth<0.3.0,>=0.2.12
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: filelock in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gdown>=4.4.0->flair->-r ./requirements.txt (line 15)) (3.8.0)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim>=4.2.0->flair->-r ./requirements.txt (line 15)) (5.2.1)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.3.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.9/171.9 kB 36.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from huggingface-hub>=0.10.0->flair->-r ./requirements.txt (line 15)) (4.4.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 78.8 MB/s eta 0:00:00
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from langdetect>=1.0.9->flair->-r ./requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud==1.9.3->-r ./requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.9.3->-r ./requirements.txt (line 3)) (4.37.4)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.9.3->-r ./requirements.txt (line 3)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.9.3->-r ./requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud==1.9.3->-r ./requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from mpld3>=0.3->flair->-r ./requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->deep-translator->-r ./requirements.txt (line 9)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->deep-translator->-r ./requirements.txt (line 9)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->deep-translator->-r ./requirements.txt (line 9)) (2.1.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 100.9 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 104.2 MB/s eta 0:00:00
# Collecting tokenizers<0.19,>=0.14
#   Downloading tokenizers-0.15.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 99.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair->-r ./requirements.txt (line 15)) (3.19.6)
# Collecting accelerate>=0.21.0
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 57.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->mpld3>=0.3->flair->-r ./requirements.txt (line 15)) (2.0.0)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: psutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from accelerate>=0.21.0->transformers[sentencepiece]<5.0.0,>=4.18.0->flair->-r ./requirements.txt (line 15)) (5.9.3)
# Building wheels for collected packages: wget, nlp_id, langdetect, pptree, sqlitedict
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=02b89731a6e7270211d21fb252027d3089d65497a0240224e6488661e271c6ac
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
#   Building wheel for nlp_id (setup.py): started
#   Building wheel for nlp_id (setup.py): finished with status 'done'
#   Created wheel for nlp_id: filename=nlp_id-0.1.15.0-py3-none-any.whl size=58153910 sha256=e2866d6d94e8413975e6e8ceba1a46ff74a65b5e9ff2899f7f0d3c248c6dfe51
#   Stored in directory: /root/.cache/pip/wheels/9f/f7/4a/9eaf35f0a6e4149dc8763d1e7ced5b6c0f208a141913525f03
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993241 sha256=9764a9257dd439f3d8e14a20e05fa2bdfe8202b499864e40685e044f02b04c80
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
#   Building wheel for pptree (setup.py): started
#   Building wheel for pptree (setup.py): finished with status 'done'
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4629 sha256=3205efe1144a8b23cfc3db99c8943c37e624dc8fe992e2164b72955e04a7fe3d
#   Stored in directory: /root/.cache/pip/wheels/52/0e/51/514e690004ea9713bc3fdb678d5e2768fcc597d0c3b6a3abd2
#   Building wheel for sqlitedict (setup.py): started
#   Building wheel for sqlitedict (setup.py): finished with status 'done'
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16868 sha256=72f221e1ef489ef6bdce917712829ecc8d358f913adb1903b0ebc206d0c42ccd
#   Stored in directory: /root/.cache/pip/wheels/f6/48/c4/942f7a1d556fddd2348cb9ac262f251873dfd8a39afec5678e
# Successfully built wget nlp_id langdetect pptree sqlitedict
# Installing collected packages: wget, wcwidth, sqlitedict, sentencepiece, Sastrawi, pptree, janome, appdirs, unidecode, tomli, semver, segtok, safetensors, pyyaml, PySocks, nltk, more-itertools, langdetect, iniconfig, ftfy, fsspec, exceptiongroup, emoji, deprecated, conllu, xgboost, wikipedia-api, scikit-learn, pytorch-revgrad, pytest, kbbi, huggingface-hub, gensim, deep-translator, wordcloud, tokenizers, nlp_id, mpld3, gdown, bpemb, accelerate, transformers, transformer-smaller-training-vocab, flair
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Not uninstalling wcwidth at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'wcwidth'. No files were found to uninstall.
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Not uninstalling nltk at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'nltk'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.2
#     Not uninstalling scikit-learn at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# Successfully installed PySocks-1.7.1 Sastrawi-1.0.1 accelerate-0.28.0 appdirs-1.4.4 bpemb-0.3.5 conllu-4.5.3 deep-translator-1.11.4 deprecated-1.2.14 emoji-2.10.1 exceptiongroup-1.2.0 flair-0.13.1 fsspec-2024.3.0 ftfy-6.2.0 gdown-5.1.0 gensim-4.3.2 huggingface-hub-0.21.4 iniconfig-2.0.0 janome-0.5.0 kbbi-0.4.3 langdetect-1.0.9 more-itertools-10.2.0 mpld3-0.5.10 nlp_id-0.1.15.0 nltk-3.8.1 pptree-3.1 pytest-7.3.1 pytorch-revgrad-0.2.0 pyyaml-6.0.1 safetensors-0.4.2 scikit-learn-1.2.2 segtok-1.5.11 semver-3.0.2 sentencepiece-0.1.99 sqlitedict-2.1.0 tokenizers-0.15.2 tomli-2.0.1 transformer-smaller-training-vocab-0.3.3 transformers-4.38.2 unidecode-1.3.8 wcwidth-0.2.13 wget-3.2 wikipedia-api-0.6.0 wordcloud-1.9.3 xgboost-2.0.3
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2b3c5800-c216-4f08-93af-5173ca1bb328' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
